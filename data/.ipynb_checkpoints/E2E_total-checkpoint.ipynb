# %%
#This is program for count E2E research

# %%
import pandas as pd
import arxiv

# %%
results = client.results(search)
def convert_to_str(vals):  # 文字列に変換
    if isinstance(vals, list):
        return list(map(str, vals))
    elif vals is None:
        return vals
    else:
        return str(vals)
        
def create_df(results):
    res0 = []
    for res in results:
        res_dict = dict(
            entry_id = res.entry_id,
            pdf_url = res.pdf_url,
            updated = res.updated, 
            published = res.published, 
            title = res.title, 
            authors = convert_to_str(res.authors),  # 文字列に変換
            summary = res.summary,
            comment = res.comment,
            journal_ref = res.journal_ref,
            doi = res.doi,
            primary_category = res.primary_category,
            categories = res.categories,
            links = convert_to_str(res.links),  # 文字列に変換
        )
        res0.append(res_dict)
    df = pd.DataFrame(res0)
    ndata = len(df)
    return df

df = create_df(results)

# %%
client = arxiv.Client(
    page_size = 100,
    delay_seconds = 3.0,
    num_retries = 10,      # 間欠障害が前提なので回数を確保する
)
search = arxiv.Search(
    query = 'abs:"autonomous driving" AND (abs:"E2E" OR abs:"End to End" OR "End-to-End")',
    max_results = 1000,
    sort_by = arxiv.SortCriterion.SubmittedDate,
    sort_order = arxiv.SortOrder.Descending,
)
df = create_df(client.results(search))
print(len(df))
query = 'abs:"autonomous driving" AND (abs:"E2E" OR abs:"End to End" OR "End-to-End")',
# Out:
# 1000

# %%
import urllib.parse, urllib.request
import xml.etree.ElementTree as ET

NS = {'opensearch': 'http://a9.com/-/spec/opensearch/1.1/'}

def arxiv_total(query: str) -> int:
    url = ('http://export.arxiv.org/api/query?search_query='
           + urllib.parse.quote(query) + '&max_results=1')
    with urllib.request.urlopen(url) as r:
        root = ET.fromstring(r.read())
    return int(root.find('opensearch:totalResults', NS).text)

print(arxiv_total(query))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 13
#       9     with urllib.request.urlopen(url) as r:
#      10         root = ET.fromstring(r.read())
#      11     return int(root.find('opensearch:totalResults', NS).text)
#      12
# ---> 13 print(arxiv_total(query))
#
# Cell In[11], line 8, in arxiv_total(query)
#       6 def arxiv_total(query: str) -> int:
#       7     url = ('http://export.arxiv.org/api/query?search_query='
# ----> 8            + urllib.parse.quote(query) + '&max_results=1')
#       9     with urllib.request.urlopen(url) as r:
#      10         root = ET.fromstring(r.read())
#      11     return int(root.find('opensearch:totalResults', NS).text)
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/parse.py:929, in quote(string, safe, encoding, errors)
#     927     if errors is not None:
#     928         raise TypeError("quote() doesn't support 'errors' for bytes")
# --> 929 return quote_from_bytes(string, safe)
#
# File ~/.local/share/uv/python/cpython-3.13.13-macos-aarch64-none/lib/python3.13/urllib/parse.py:959, in quote_from_bytes(bs, safe)
#     954 """Like quote(), but accepts a bytes object rather than a str, and does
#     955 not perform string-to-bytes encoding.  It always returns an ASCII string.
#     956 quote_from_bytes(b'abc def\x3f') -> 'abc%20def%3f'
#     957 """
#     958 if not isinstance(bs, (bytes, bytearray)):
# --> 959     raise TypeError("quote_from_bytes() expected bytes")
#     960 if not bs:
#     961     return ''
#
# TypeError: quote_from_bytes() expected bytes

# %%
import numpy as np

def create_url(aid: str):
    apath = aid.split("/")[-1].split("v")[0]
    arxiv_id = f'ARXIV:{apath}'
    search_url = f'{semantic_base_url}/{arxiv_id}' + '?fields=' + fields 
    return arxiv_id

semantic_base_url = 'https://api.semanticscholar.org/graph/v1/paper'  # Semantic ScholarのベースURL
fields = 'citationCount,influentialCitationCount,referenceCount'  # サイトから取得する追加項
df['arxiv_id'] = df['entry_id'].apply(create_url)
tcol = fields.split(",") 
df[tcol] = np.nan  # 初期化

# %%
import requests
import time

HEADERS = {}   # APIキー取得後は {"x-api-key": API_KEY}

def post_batch(batch, max_retry=6):
    for attempt in range(max_retry):
        r = requests.post(semantic_base_url + '/batch',
                          params={'fields': fields}, json={"ids": batch},
                          headers=HEADERS, timeout=30)
        if r.status_code == 200:
            return r.json()
        if r.status_code in (429, 500, 502, 503, 504):
            wait = int(r.headers.get('Retry-After', 0)) or 5 * 2 ** attempt
            print(f'  {r.status_code}: retry in {wait}s (attempt {attempt+1})')
            time.sleep(wait)
            continue
        r.raise_for_status()
    return None


def get_citation_batch(df, start=0, batch_size=500):
    outs = []
    data = df['arxiv_id'].tolist()
    for i in range(start, len(data), batch_size):
        batch = data[i:i+batch_size]
        payload = post_batch(batch)
        if payload is None:
            print('Error: giving up. restart with start=', i)
            break
        rows = {pid: rec for pid, rec in zip(batch, payload) if rec is not None}
        if rows:
            outs.append(pd.DataFrame.from_dict(rows, orient="index"))
        time.sleep(5)
    if not outs:
        return df
    res = pd.concat(outs).rename_axis('arxiv_id').reset_index()
    return df.merge(res[['arxiv_id'] + tcol], on='arxiv_id', how='left')


start = 0  # 開始行
batch_size = 500  # バッチ数。500以下
df = get_citation_batch(df, start=start, batch_size=batch_size)
# Out:
#   429: retry in 5s (attempt 1)

# %%
df = df.drop(columns=[c + '_x' for c in tcol])
df = df.rename(columns={c + '_y': c for c in tcol})

# %%
df.sort_values(['influentialCitationCount'],ascending=False)
# Out:
#                               entry_id                             pdf_url  \
# 812  http://arxiv.org/abs/2303.12077v3  https://arxiv.org/pdf/2303.12077v3
# 853  http://arxiv.org/abs/2208.14437v2  https://arxiv.org/pdf/2208.14437v2
# 873  http://arxiv.org/abs/2205.15997v1  https://arxiv.org/pdf/2205.15997v1
# 726  http://arxiv.org/abs/2312.14150v3  https://arxiv.org/pdf/2312.14150v3
# 645  http://arxiv.org/abs/2406.15349v2  https://arxiv.org/pdf/2406.15349v2
# ..                                 ...                                 ...
# 131  http://arxiv.org/abs/2604.18918v1  https://arxiv.org/pdf/2604.18918v1
# 461  http://arxiv.org/abs/2505.15005v1  https://arxiv.org/pdf/2505.15005v1
# 0    http://arxiv.org/abs/2607.20988v1  https://arxiv.org/pdf/2607.20988v1
# 329  http://arxiv.org/abs/2510.00060v3  https://arxiv.org/pdf/2510.00060v3
# 466  http://arxiv.org/abs/2505.06780v2  https://arxiv.org/pdf/2505.06780v2
#
#                       updated                 published  \
# 812 2023-08-24 08:15:35+00:00 2023-03-21 17:59:22+00:00
# 853 2023-01-30 02:39:49+00:00 2022-08-30 17:55:59+00:00
# 873 2022-05-31 17:57:19+00:00 2022-05-31 17:57:19+00:00
# 726 2025-01-16 10:57:44+00:00 2023-12-21 18:59:12+00:00
# 645 2024-10-31 17:58:34+00:00 2024-06-21 17:59:02+00:00
# ..                        ...                       ...
# 131 2026-04-20 23:49:45+00:00 2026-04-20 23:49:45+00:00
# 461 2025-05-21 01:23:31+00:00 2025-05-21 01:23:31+00:00
# 0   2026-07-23 07:11:41+00:00 2026-07-23 07:11:41+00:00
# 329 2026-02-27 09:00:30+00:00 2025-09-29 05:14:18+00:00
# 466 2025-05-13 02:40:38+00:00 2025-05-10 23:29:35+00:00
#
#                                                  title  \
# 812  VAD: Vectorized Scene Representation for Effic...
# 853  MapTR: Structured Modeling and Learning for On...
# 873  TransFuser: Imitation with Transformer-Based S...
# 726  DriveLM: Driving with Graph Visual Question An...
# 645  NAVSIM: Data-Driven Non-Reactive Autonomous Ve...
# ..                                                 ...
# 131  From Particles to Perils: SVGD-Based Hazardous...
# 461  UniSTPA: A Safety Analysis Framework for End-t...
# 0    HyWorldVLA: A Vision-Language-Action Model wit...
# 329  Less is More: Lean yet Powerful Vision-Languag...
# 466  Work-in-Progress: Multi-Deadline DAG Schedulin...
#
#                                                authors  \
# 812  [Bo Jiang, Shaoyu Chen, Qing Xu, Bencheng Liao...
# 853  [Bencheng Liao, Shaoyu Chen, Xinggang Wang, Ti...
# 873  [Kashyap Chitta, Aditya Prakash, Bernhard Jaeg...
# 726  [Chonghao Sima, Katrin Renz, Kashyap Chitta, L...
# 645  [Daniel Dauner, Marcel Hallgarten, Tianyu Li, ...
# ..                                                 ...
# 131  [Linfeng Liang, Xiao Cheng, Tsong Yueh Chen, X...
# 461  [Hongrui Kou, Zhouhang Lyu, Ziyu Wang, Cheng W...
# 0             [Quanfu Yu, Xian Wu, Hao Xu, Liulong Ma]
# 329  [Sheng Yang, Tong Zhan, Guancheng Chen, Yanfen...
# 466                       [Atsushi Yano, Takuya Azumi]
#
#                                                summary  \
# 812  Autonomous driving requires a comprehensive un...
# 853  High-definition (HD) map provides abundant and...
# 873  How should we integrate representations from c...
# 726  We study how vision-language models (VLMs) tra...
# 645  Benchmarking vision-based driving policies is ...
# ..                                                 ...
# 131  Simulation-based testing of autonomous driving...
# 461  As autonomous driving technology continues to ...
# 0    Vision-Language-Action (VLA) models augmented ...
# 329  In this work, we reconceptualize autonomous dr...
# 466  Autoware is an autonomous driving system imple...
#
#                                                comment  \
# 812  Accepted to ICCV 2023. Code&Demos: https://git...
# 853  Accepted to ICLR 2023 as Spotlight Presentatio...
# 873  arXiv admin note: text overlap with arXiv:2104...
# 726                Accepted to ECCV 2024 as Oral paper
# 645               NeurIPS 2024 Datasets and Benchmarks
# ..                                                 ...
# 131                                                NaN
# 461                                                NaN
# 0                             20 pages with 13 figures
# 329                                                NaN
# 466                                                NaN
#
#                                            journal_ref  \
# 812                                                NaN
# 853                                                NaN
# 873                                                NaN
# 726                                                NaN
# 645                                                NaN
# ..                                                 ...
# 131  Proceedings of the ACM on Software Engineering...
# 461                                                NaN
# 0                                                  NaN
# 329                                                NaN
# 466                                                NaN
#
#                               doi primary_category  \
# 812                           NaN            cs.RO
# 853                           NaN            cs.CV
# 873                           NaN            cs.CV
# 726                           NaN            cs.CV
# 645                           NaN            cs.CV
# ..                            ...              ...
# 131               10.1145/3808153            cs.SE
# 461                           NaN            cs.RO
# 0                             NaN            cs.CV
# 329                           NaN            cs.CV
# 466  10.1109/RTSS62706.2024.00049            cs.OS
#
#                        categories  \
# 812                [cs.RO, cs.CV]
# 853                [cs.CV, cs.RO]
# 873  [cs.CV, cs.AI, cs.LG, cs.RO]
# 726                       [cs.CV]
# 645  [cs.CV, cs.AI, cs.LG, cs.RO]
# ..                            ...
# 131                [cs.SE, cs.LG]
# 461                [cs.RO, cs.SE]
# 0                  [cs.CV, cs.AI]
# 329         [cs.CV, cs.AI, cs.RO]
# 466                       [cs.OS]
#
#                                                  links          arxiv_id  \
# 812  [https://arxiv.org/abs/2303.12077v3, https://a...  ARXIV:2303.12077
# 853  [https://arxiv.org/abs/2208.14437v2, https://a...  ARXIV:2208.14437
# 873  [https://arxiv.org/abs/2205.15997v1, https://a...  ARXIV:2205.15997
# 726  [https://arxiv.org/abs/2312.14150v3, https://a...  ARXIV:2312.14150
# 645  [https://arxiv.org/abs/2406.15349v2, https://a...  ARXIV:2406.15349
# ..                                                 ...               ...
# 131  [https://arxiv.org/abs/2604.18918v1, https://a...  ARXIV:2604.18918
# 461  [https://arxiv.org/abs/2505.15005v1, https://a...  ARXIV:2505.15005
# 0    [https://arxiv.org/abs/2607.20988v1, https://a...  ARXIV:2607.20988
# 329  [https://arxiv.org/abs/2510.00060v3, https://a...  ARXIV:2510.00060
# 466  [https://arxiv.org/abs/2505.06780v2, https://a...  ARXIV:2505.06780
#
#      citationCount  influentialCitationCount  referenceCount
# 812          739.0                     141.0            52.0
# 853          419.0                     111.0            44.0
# 873          762.0                     110.0           134.0
# 726          609.0                      86.0           101.0
# 645          354.0                      83.0            66.0
# ..             ...                       ...             ...
# 131            0.0                       0.0            78.0
# 461            1.0                       0.0            23.0
# 0              0.0                       0.0             0.0
# 329            NaN                       NaN             NaN
# 466            NaN                       NaN             NaN
#
# [1000 rows x 17 columns]

# %%
NS = {'opensearch': 'http://a9.com/-/spec/opensearch/1.1/'}
for y in range(2015, 2027):
    q = f'abs:"autonomous driving" AND submittedDate:[{y}01010000 TO {y}12312359]'
    q = f'abs:"autonomous driving" AND (abs:"E2E" OR abs:"End to End" OR "End-to-End")AND submittedDate:[{y}01010000 TO {y}12312359]'

    print(y, arxiv_total(q))
    time.sleep(3)
# Out:
# 2015 0
# 2016 5
# 2017 10
# 2018 23
# 2019 35
# 2020 46
# 2021 68
# 2022 78
# 2023 105
# 2024 171
# 2025 324
# 2026 227

# %%
print(df['published'].dt.year.value_counts().sort_index())
# Out:
# published
# 2020     27
# 2021     68
# 2022     78
# 2023    105
# 2024    171
# 2025    324
# 2026    227
# Name: count, dtype: int64
